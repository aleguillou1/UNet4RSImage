# %%
import os
import numpy as np
import rasterio
from rasterio.windows import Window
from rasterio.merge import merge
from osgeo import gdal
import subprocess
import tensorflow as tf
from tqdm import tqdm
import tempfile
from rasterio.enums import Resampling
# Out:
# 2025-04-09 20:40:43.966916: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-09 20:40:44.363156: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-04-09 20:40:44.363207: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-09 20:40:44.438972: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-09 20:40:44.573125: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-09 20:40:45.564876: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def create_patches(input_tiff, output_dir, patch_size=224, overlap=125):
    """
    Splits a satellite image into patches with overlap and saves the patches.
    
    Args:
        input_tiff (str): Path to the input satellite image in TIFF format.
        output_dir (str): Directory where patches will be saved.
        patch_size (int): Size of each patch (default is 224x224 pixels).
        overlap (int): Number of pixels of overlap between patches.
    """
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # Open the satellite image
    with rasterio.open(input_tiff) as src:
        width, height = src.width, src.height  # Get the image dimensions
        channels = src.count  # Get the number of bands (channels) in the image
        
        # Calculate the stride (the step size between patches)
        stride = patch_size - overlap
        
        # Initialize a counter to name the patches
        patch_count = 0
        
        # Loop through the image to extract patches
        for y in range(0, height - overlap, stride):
            for x in range(0, width - overlap, stride):
                # Check if the window stays within the image boundaries
                window = Window(x, y, patch_size, patch_size)
                if x + patch_size > width or y + patch_size > height:
                    continue
                
                # Read the data within the window (patch)
                patch = src.read(window=window)
                
                # Save the patch as a separate TIFF file
                patch_path = os.path.join(output_dir, f'patch_{patch_count}.tif')
                with rasterio.open(
                    patch_path,
                    'w',
                    driver='GTiff',
                    height=patch.shape[1],  # Height of the patch
                    width=patch.shape[2],   # Width of the patch
                    count=channels,         # Number of bands
                    dtype=patch.dtype,     # Data type of the patch
                    crs=src.crs,            # Coordinate Reference System
                    transform=rasterio.windows.transform(window, src.transform),  # Geospatial transform
                ) as dst:
                    dst.write(patch)  # Write the patch data
                
                patch_count += 1  # Increment patch counter
    
    # Print the number of patches created
    print(f"Splitting completed: {patch_count} patches saved in {output_dir}.")

# Example usage of the function
input_tiff = "/mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/Image.tif"  # Path to your satellite image
output_dir = "/mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/directory"  # Directory to save the patches

# Call the function with a patch size of 224x224 and overlap of 32 pixels (you can change , if you increase the overlap the calculation time will be higher but with less artefacts)
create_patches(input_tiff, output_dir, patch_size=224, overlap=125)
# Out:
# Splitting completed: 9000 patches saved in /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/directory.

# %%
# Image normalization function
def normalize_img(img):
    """Normalizes an image between 0 and 1."""
    return img / np.max(img)

# Function to load a test image with its georeferencing information
def load_test_image(image_path):
    """
    Loads a satellite image and normalizes it.
    
    Args:
        image_path (str): Path to the satellite image.
    
    Returns:
        img (ndarray): Normalized image.
        transform (Affine): Georeferencing transformation.
        crs (CRS): Coordinate reference system.
    """
    import tifffile as tiff
    img = tiff.imread(image_path).astype(np.float32)
    img = normalize_img(img)
    img = np.expand_dims(img, axis=0)  # Add a batch dimension
    
    # Read geospatial metadata
    with rasterio.open(image_path) as src:
        transform = src.transform
        crs = src.crs
        
    return img, transform, crs

# Function to predict all patches in a directory
def predict_patches(model_path, input_dir, output_dir):
    """
    Makes predictions for each patch in the input directory.
    
    Args:
        model_path (str): Path to the saved model (SavedModel).
        input_dir (str): Directory containing the input patches.
        output_dir (str): Directory to save the predictions.
    """
    # Load the model
    model = tf.keras.models.load_model(model_path)
    
    # Create the output directory if it doesn't exist
    os.makedirs(output_dir, exist_ok=True)
    
    # List input patch files
    patch_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]
    
    for patch_file in patch_files:
        patch_path = os.path.join(input_dir, patch_file)
        
        # Load the test image
        test_image, transform, crs = load_test_image(patch_path)
        
        # Make the prediction
        prediction = model.predict(test_image)
        predicted_mask = tf.argmax(prediction, axis=-1)
        predicted_mask = tf.squeeze(predicted_mask).numpy().astype(np.uint8)
        
        # Define the output path for the predicted mask
        predicted_mask_path = os.path.join(output_dir, f"pred_{patch_file}")
        
        # Save the predicted mask with geospatial information
        with rasterio.open(patch_path) as src:
            meta = src.meta  # Get the metadata
            meta.update(driver='GTiff', dtype=rasterio.uint8, count=1)  # Adjust for the mask
            
            # Save the predicted mask
            with rasterio.open(predicted_mask_path, 'w', **meta) as dst:
                dst.write(predicted_mask, 1)  # Write the mask as the first band
        
        print(f"Prediction saved: {predicted_mask_path}")

# Parameters
model_path = '/mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/saved_model'  # Path to your SavedModel
input_dir = '/mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/directory'       # Directory containing the input patches
output_dir = '/mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/'  # Directory to save the predictions

# Run the prediction
predict_patches(model_path, input_dir, output_dir)
# Out:
# 2025-04-09 20:45:58.205304: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-09 20:45:58.362566: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-09 20:45:58.362611: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-09 20:45:58.364852: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-09 20:45:58.364922: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-09 20:45:58.364947: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-09 20:45:58.501384: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-09 20:45:58.501448: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-09 20:45:58.501454: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2025-04-09 20:45:58.501482: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2025-04-09 20:45:58.501499: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 7537 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2025-04-09 20:46:02.320230: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2025-04-09 20:46:02.525584: I external/local_tsl/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 1/1 [==============================] - 2s 2s/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_0.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_10.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_100.tif
# 1/1 [==============================] - 0s 18ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1000.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1001.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1002.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1003.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1004.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1005.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1006.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1007.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1008.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1009.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_101.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1010.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1011.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1012.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1013.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1014.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1015.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1016.tif
# 1/1 [==============================] - 0s 18ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1017.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1018.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1019.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_102.tif
# 1/1 [==============================] - 0s 18ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1020.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1021.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1022.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1023.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1024.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1025.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1026.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1027.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1028.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1029.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_103.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1030.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1031.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1032.tif
# 1/1 [==============================] - 0s 14ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1033.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1034.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1035.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1036.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1037.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1038.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1039.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_104.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1040.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1041.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1042.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1043.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1044.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1045.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1046.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1047.tif
# 1/1 [==============================] - 0s 18ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1048.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1049.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_105.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1050.tif
# 1/1 [==============================] - 0s 18ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1051.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1052.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1053.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1054.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1055.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1056.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1057.tif
# 1/1 [==============================] - 0s 23ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1058.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1059.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_106.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1060.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1061.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1062.tif
# 1/1 [==============================] - 0s 18ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1063.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1064.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1065.tif
# 1/1 [==============================] - 0s 18ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1161.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1162.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1163.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1164.tif
# 1/1 [==============================] - 0s 14ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1165.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1166.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1167.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1168.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1169.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_117.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1170.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1171.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1172.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1173.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1174.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1189.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_119.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1190.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1191.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1192.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1193.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1194.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1195.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1196.tif
# 1/1 [==============================] - 0s 18ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1197.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1198.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1199.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_12.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_120.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1200.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1201.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1216.tif
# 1/1 [==============================] - 0s 18ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1217.tif
# 1/1 [==============================] - 0s 21ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1218.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1219.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_122.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1220.tif
# 1/1 [==============================] - 0s 18ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1221.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1222.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1223.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1224.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1225.tif
# 1/1 [==============================] - 0s 15ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1226.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1227.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1228.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_1229.tif
# 1/1 [==============================] - 0s 22ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_929.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_93.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_930.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_931.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_932.tif
# 1/1 [==============================] - 0s 18ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_933.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_934.tif
# 1/1 [==============================] - 0s 21ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_935.tif
# 1/1 [==============================] - 0s 21ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_936.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_937.tif
# 1/1 [==============================] - 0s 21ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_938.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_939.tif
# 1/1 [==============================] - 0s 17ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_94.tif
# 1/1 [==============================] - 0s 21ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_940.tif
# 1/1 [==============================] - 0s 16ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_941.tif
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_957.tif
# 1/1 [==============================] - 0s 21ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_958.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_959.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_96.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_960.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_961.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_962.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_963.tif
# 1/1 [==============================] - 0s 21ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_964.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_965.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_966.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_967.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_968.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_969.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_97.tif
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_984.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_985.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_986.tif
# 1/1 [==============================] - 0s 22ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_987.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_988.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_989.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_99.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_990.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_991.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_992.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_993.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_994.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_995.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_996.tif
# 1/1 [==============================] - 0s 19ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_997.tif
# 1/1 [==============================] - 0s 20ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_998.tif
# 1/1 [==============================] - 0s 21ms/step
# Prediction saved: /mnt/c/Users/PC/Bureau/Travail/Thèse_SSD/Unet_RS/Unet4RSImage/RTU/test2/predictions/pred_patch_999.tif

# %%
import os
import numpy as np
import rasterio
from rasterio.merge import merge
from rasterio.windows import Window
from tqdm import tqdm
import tempfile
from rasterio.enums import Resampling

def reconstruct_from_patches(input_dir, output_path, overlap=200, buffer_size=50):
    """
    Reconstructs a large-scale image from GeoTIFF patches with overlap handling.
    
    Args:
        input_dir (str): Directory containing the GeoTIFF patches
        output_path (str): Output path for the reconstructed image
        overlap (int): Number of pixels of overlap between patches
        buffer_size (int): Area to ignore at the edges of each patch to avoid artifacts
    """
    # List all GeoTIFF files in the directory
    patch_files = [f for f in os.listdir(input_dir) if f.lower().endswith(('.tif', '.tiff'))]
    if not patch_files:
        raise ValueError("No GeoTIFF files found in the input directory")

    # Load metadata from the first patch
    first_patch = os.path.join(input_dir, patch_files[0])
    with rasterio.open(first_patch) as src:
        meta = src.meta.copy()
        dtype = src.dtypes[0]
        count = src.count

    # Create a temporary directory for processed patches
    temp_dir = tempfile.mkdtemp()
    processed_patches = []

    print("Processing individual patches...")
    for patch_file in tqdm(patch_files):
        patch_path = os.path.join(input_dir, patch_file)
        temp_path = os.path.join(temp_dir, f"processed_{patch_file}")
        
        with rasterio.open(patch_path) as src:
            # Read the data with a reduced window to avoid borders
            height, width = src.shape
            window = Window(
                buffer_size, 
                buffer_size, 
                width - 2 * buffer_size, 
                height - 2 * buffer_size
            )
            
            # Read the data within the window
            data = src.read(window=window)
            
            # Compute the new transform for this window
            transform = src.window_transform(window)
            
            # Update metadata
            meta.update({
                'height': window.height,
                'width': window.width,
                'transform': transform
            })
            
            # Write the processed patch
            with rasterio.open(temp_path, 'w', **meta) as dst:
                dst.write(data)
        
        processed_patches.append(temp_path)

    print("Merging processed patches...")
    # Merge all processed patches
    src_files_to_mosaic = [rasterio.open(patch) for patch in processed_patches]
    mosaic, out_trans = merge(
        src_files_to_mosaic,
        method='first',  # Takes the first non-null value (avoids overlaps)
        resampling=Resampling.nearest
    )

    # Close all opened files
    for src in src_files_to_mosaic:
        src.close()

    # Update final metadata
    meta.update({
        'driver': 'GTiff',
        'height': mosaic.shape[1],
        'width': mosaic.shape[2],
        'transform': out_trans,
        'compress': 'lzw',
        'nodata': 8,
        'dtype': dtype,
        'count': count
    })

    print("Writing the final image...")
    # Write the final image
    with rasterio.open(output_path, 'w', **meta) as dst:
        dst.write(mosaic)

    # Clean up temporary files
    for patch in processed_patches:
        try:
            os.remove(patch)
        except:
            pass
    try:
        os.rmdir(temp_dir)
    except:
        pass

    print(f"Reconstruction completed. Image saved at: {output_path}")


if __name__ == "__main__":
    # Example usage
    input_directory = "path/to/your/directory"
    output_file = "path/to/your/output.tif"
    
    reconstruct_from_patches(
        input_dir=input_directory,
        output_path=output_file,
        overlap=125,  # Matches your description
        buffer_size=40  # Area to ignore at the borders
    )
